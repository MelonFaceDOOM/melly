# %%
pos = 12
before = "asda[b]asdsa[/b]1"
after = "asda<strong>asdsa</strong>1"
pos += len(after) - len (before) + len("[/b]")
pos
#after[pos]

# %%
import json
import os
from tags import tags
import re 

class FormatTag():
    def __init__(self, name, start, end, output_template, format_func):
        self.name = name
        self.start = start
        self.end = end
        self.format_func = format_func
        self.output_template = output_template
        self.openings = []
        

    def close(self, unformatted, end_pos):
        if self.openings:
            pre_text = unformatted[:self.openings[-1]]
            post_text = unformatted[end_pos + len(self.end):]
            tagged_text = unformatted[self.openings[-1]: end_pos+len(self.end)]
            formatted = self.format_func(self, tagged_text)            
            self.openings = self.openings[:-1]
            return pre_text + formatted + post_text
        else:
            return unformatted


def create_tags():
    format_tags = []
    for t in tags:
        format_tags.append(FormatTag(name=t['name'], start=t['start'], end=t['end'],
                              output_template=t['output_template'], format_func=t['format_func']))
    return format_tags
    

def parse(s):
    # the FormatTag class keeps track of information for each tag type, while variables within this function
    # are responsible for keeping track of inter-tag information and adjusting the tag values based on what happens
    # as the string is parsed
    
    replace = {
        u'<': u'&lt;',
        u'>': u'&gt;',
        u'&': u'&amp;',
        u'\n': u'<br/>'
    }
    
    for key in replace.keys():
        s = s.replace(key, replace[key])

    tags = create_tags()
    open_bracket_pos = None
    pos = 0
    while True:
        if pos >= len(s):
            return s
        # encountering end tags
        elif s[pos:pos+2] == "[/":
            tag_identified = False
            for tag in tags:
                if s[pos:].startswith(tag.end):
                    tag_identified = True
                    # check if there is an opening associated with this
                    if tag.openings:
                        tag_opening_pos = tag.openings[-1]
                        len_before = len(s)
                        s = tag.close(s, pos)
                        
                        # find if any tags were between the start and close of the tag that was just closed
                        inbetween_tags = False
                        for _tag in tags:
                            for i, _tag_opening_pos in enumerate(_tag.openings):
                                if _tag_opening_pos > tag_opening_pos and _tag_opening_pos < pos:
                                    inbetween_tags = True
                                    del _tag.openings[i] # delete in-between tags as their position value is no longer valid

                        if inbetween_tags:
                        # restart the parser at that the start location of the tag that was closed 
                            pos = tag_opening_pos
                            break

                        # if there were no tags between, adjust the frame to the ending of this tag pairing)
                        pos += len(tag.end)+len(s)-len_before
                        break
                    else:
                        # if there is an end tag with no opening tag, skip past it.
                        pos += len (tag.end)
                        break
                        
            if not tag_identified:
                pos += 2
                    
            
                
        # encountering the start of opening tags
        elif s[pos] == "[":
            open_bracket_pos = pos
            pos += 1
        # encountering the end of opening tags
        elif s[pos] == "]":
            if open_bracket_pos is not None:
                possible_start_tag = s[open_bracket_pos:pos+1]
                for tag in tags:
                    if bool(re.match(tag.start, possible_start_tag)):
                        tag.openings.append(open_bracket_pos)
                        open_bracket_pos = None
                        break
            pos += 1
        else:
            pos += 1
        print(pos, s[:pos])

# %%
parse("[quote]http://www.google.com/intl/en_ALL/images/logo.gif[/quote]")
# Out:
# 1 [
# 2 [q
# 3 [qu
# 4 [quo
# 5 [quot
# 6 [quote
# 7 [quote]
# 8 [quote]h
# 9 [quote]ht
# 10 [quote]htt
# 11 [quote]http
# 12 [quote]http:
# 13 [quote]http:/
# 14 [quote]http://
# 15 [quote]http://w
# 16 [quote]http://ww
# 17 [quote]http://www
# 18 [quote]http://www.
# 19 [quote]http://www.g
# 20 [quote]http://www.go
# 21 [quote]http://www.goo
# 22 [quote]http://www.goog
# 23 [quote]http://www.googl
# 24 [quote]http://www.google
# 25 [quote]http://www.google.
# 26 [quote]http://www.google.c
# 27 [quote]http://www.google.co
# 28 [quote]http://www.google.com
# 29 [quote]http://www.google.com/
# 30 [quote]http://www.google.com/i
# 31 [quote]http://www.google.com/in
# 32 [quote]http://www.google.com/int
# 33 [quote]http://www.google.com/intl
# 34 [quote]http://www.google.com/intl/
# 35 [quote]http://www.google.com/intl/e
# 36 [quote]http://www.google.com/intl/en
# 37 [quote]http://www.google.com/intl/en_
# 38 [quote]http://www.google.com/intl/en_A
# 39 [quote]http://www.google.com/intl/en_AL
# 40 [quote]http://www.google.com/intl/en_ALL
# 41 [quote]http://www.google.com/intl/en_ALL/
# 42 [quote]http://www.google.com/intl/en_ALL/i
# 43 [quote]http://www.google.com/intl/en_ALL/im
# 44 [quote]http://www.google.com/intl/en_ALL/ima
# 45 [quote]http://www.google.com/intl/en_ALL/imag
# 46 [quote]http://www.google.com/intl/en_ALL/image
# 47 [quote]http://www.google.com/intl/en_ALL/images
# 48 [quote]http://www.google.com/intl/en_ALL/images/
# 49 [quote]http://www.google.com/intl/en_ALL/images/l
# 50 [quote]http://www.google.com/intl/en_ALL/images/lo
# 51 [quote]http://www.google.com/intl/en_ALL/images/log
# 52 [quote]http://www.google.com/intl/en_ALL/images/logo
# 53 [quote]http://www.google.com/intl/en_ALL/images/logo.
# 54 [quote]http://www.google.com/intl/en_ALL/images/logo.g
# 55 [quote]http://www.google.com/intl/en_ALL/images/logo.gi
# 56 [quote]http://www.google.com/intl/en_ALL/images/logo.gif
# 74 <blockquote>http://www.google.com/intl/en_ALL/images/logo.gif</blockquote>
# '<blockquote>http://www.google.com/intl/en_ALL/images/logo.gif</blockquote>'
